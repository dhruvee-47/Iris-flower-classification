# %% [markdown]
#    <center><h2><font color="orange"> Iris Flower Classification Using Decision Tree Algorithm : </h2></font>
#     <h3> by - Dhruvee Vadhvana </h3></center>

# %% [markdown]
# ![](img.png)

# %% [markdown]
# <h1><center><font color="#009999">Iris Flower Classification Using Decision Tree Algorithm : </font></h1></center>

# %% [markdown]
# - The goal of the project is to classify different species of iris flowers based on their petal and sepal dimensions.
# - The dataset contains 150 samples of iris flowers, where each sample consists of four features - sepal length, sepal width, petal length, and petal width. The target variable is the species of iris flower, which can take three possible values - setosa, versicolor, and virginica.
# - The project involves building a machine learning model that can accurately classify new samples of iris flowers based on their features. This can be done using various classification algorithms such as logistic regression, decision trees, k-nearest neighbors, support vector machines, or neural networks.
# - Here we are classifying using Decision Tree Algorithm.
# - The Iris Flowers dataset contains 150 samples of iris flowers, where each sample contains four features and a target variable indicating the species of the flower. The details of the variables in the dataset are as follows:
# <ol>
#     <li>Sepal Length (in cm): This variable represents the length of the sepal of the iris flower.</li>
#     <li>Sepal Width (in cm): This variable represents the width of the sepal of the iris flower.</li>
#     <li>Petal Length (in cm): This variable represents the length of the petal of the iris flower.</li>
#     <li>Petal Width (in cm): This variable represents the width of the petal of the iris flower.</li>
#     <li>Species: This variable represents the species of the iris flower. It can take one of three possible values         : setosa, versicolor, or virginica.</li>
# </ol>
# - The target variable, "Species," is a categorical variable, represented as a string.

# %% [markdown]
# ![](irisclass.png)

# %% [markdown]
# <h2><center><font color="#730099"> Importing required libraries: </font></h2></center>

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
# %matplotlib inline 
import seaborn as sns 
import warnings 
warnings.filterwarnings("ignore")
from scipy.stats import skew,norm

# %% [markdown]
# <h2><center><font color="#730099"> Reading Dataset: </font></h2></center>

# %%
df = pd.read_csv('C:/Users/Dhruvee Vadhvana/Documents/Lets grow more/Iris.csv')
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0      1            5.1           3.5            1.4           0.2  \
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.shape
# Out:
# (150, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %% [markdown]
# <h2><center><font color="#730099"> Exploratory Data Analysis (EDA):</font></h2></center>

# %% [markdown]
# <h3><center><font color="#ff9900" > Descriptive Statistics </font></h3></center>

# %%
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %% [markdown]
# <h4><font color="red"> Checking for the Missing/Null and duplicate values :  </h4></font>

# %%
df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# <h3><center><font color="#ff9900"> Droping unwanted coulmn ("Id"): </h3></font></center>

# %%
#Id column does not have any significant information 
df.drop('Id',axis=1,inplace=True)
df.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
sns.pairplot(df,hue='Species',diag_kind="kde");

# %% [markdown]
# <h3><center><font color="#ff9900"> Distribution Plot of Features: </h3></center></font>

# %%
column=df.select_dtypes(['int64','float64']).columns

# %%
for col in df[column]:
    print(col)
    print(skew(df[col]))
    sns.distplot(df[col],color='red',fit=norm)
    plt.show()
# Out:
# SepalLengthCm
# 0.3117530585022963
# SepalWidthCm
# 0.330702812773315
# PetalLengthCm
# -0.2717119501716388
# PetalWidthCm
# -0.10394366626751729

# %% [markdown]
# <h3><center><font color="#ff9900"> BoxPlot of Features: </h3></center></font>

# %%
for col in df[column]:
    print(col)
    print(skew(df[col]))
    sns.boxplot(data=df,x='Species',y=df[col])
    plt.show()
# Out:
# SepalLengthCm
# 0.3117530585022963
# SepalWidthCm
# 0.330702812773315
# PetalLengthCm
# -0.2717119501716388
# PetalWidthCm
# -0.10394366626751729

# %% [markdown]
# <h3><center><font color="#ff9900"> PetalLength VS PetalWidth: </h3></center></font>

# %%
sns.scatterplot(data=df, x="PetalLengthCm", y="PetalWidthCm", hue='Species')
plt.title("PetalLength VS PetalWidth")
plt.legend(loc=(1,0.5))
plt.show()

# %%
df.columns
# Out:
# Index(['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %% [markdown]
# <h3><center><font color="#ff9900"> SepalLength VS SepalWidth: </h3></center></font>

# %%
sns.scatterplot(data=df, x="SepalLengthCm", y="SepalWidthCm", hue='Species')
plt.title("SepalLength VS SepalWidth")
plt.legend(loc=(1,0.5))
plt.show()

# %% [markdown]
# <h3><center><font color="#ff9900">Target Column- Species: </h3></font></center>

# %%
df['Species'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
df['Species'].value_counts()
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %% [markdown]
# <h2><center><font color="#730099">Encoding:</font></h2></center>

# %%
#label Encoder 
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
df['Species']=le.fit_transform(df['Species'])

# %%
le.classes_
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
df.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0            5.1           3.5            1.4           0.2        0
# 1            4.9           3.0            1.4           0.2        0
# 2            4.7           3.2            1.3           0.2        0
# 3            4.6           3.1            1.5           0.2        0
# 4            5.0           3.6            1.4           0.2        0

# %%
df['Species'].value_counts()
# Out:
# Species
# 0    50
# 1    50
# 2    50
# Name: count, dtype: int64

# %% [markdown]
# <h4>- Perfectly balanced Target Columns </h4>

# %% [markdown]
# <h2><center><font color="#730099">Spliting Dataset:</font></h2></center>

# %%
x=df.drop('Species',axis=1)
y=df['Species']

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest= train_test_split(x,y,test_size=0.3,random_state=42)

# %% [markdown]
# <h2><center><font color="#730099">Importing DecisionTreeClassifier :</font></h2></center>

# %%
from sklearn.tree import DecisionTreeClassifier 
dtc=DecisionTreeClassifier()

# %%
dtc.fit(xtrain,ytrain)
ypred=dtc.predict(xtest)

# %% [markdown]
# <h2><center><font color="#730099">Model Evaluation:</font></h2></center>

# %%
from sklearn.metrics import classification_report, accuracy_score,confusion_matrix

# %%
print(f'Accuracy Score:= {accuracy_score(ytest,ypred)}')
# Out:
# Accuracy Score:= 1.0

# %%
print("Classification_Report\n",classification_report(ypred,ytest))
# Out:
# Classification_Report
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        19
#            1       1.00      1.00      1.00        13
#            2       1.00      1.00      1.00        13
#
#     accuracy                           1.00        45
#    macro avg       1.00      1.00      1.00        45
# weighted avg       1.00      1.00      1.00        45

# %% [markdown]
# <p><center><h3><font color="#ff9900">Checking for the overfitting & Underfitting : </h3></font></p></center>

# %%
train= dtc.score(xtrain,ytrain)
test = dtc.score(xtest,ytest)
print(f"Training Accuracy:-{train}\nTesting Accuracy:-{test}")
# Out:
# Training Accuracy:-1.0
# Testing Accuracy:-1.0

# %% [markdown]
# <h3>- perfect model </h3>

# %% [markdown]
# <p><center><h1><font color="#730099">Scaling:</font></h1></p></center>

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()
xs_train = scaler.fit_transform(xtrain)
xs_test = scaler.transform(xtest)

# %%
dtcs = DecisionTreeClassifier()
dtcs.fit(xs_train,ytrain)
ypred=dtcs.predict(xs_test)
print(f'Accuracy Score:- {accuracy_score(ytest,ypred)}')
print("Classification_report\n",classification_report(ypred,ytest))
# Out:
# Accuracy Score:- 1.0
# Classification_report
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        19
#            1       1.00      1.00      1.00        13
#            2       1.00      1.00      1.00        13
#
#     accuracy                           1.00        45
#    macro avg       1.00      1.00      1.00        45
# weighted avg       1.00      1.00      1.00        45

# %%
train=dtcs.score(xs_train,ytrain)
test = dtcs.score(xs_test,ytest)
print(f"Training Accuracy:-{train}\n Testing Accuracy:-{test}")
# Out:
# Training Accuracy:-1.0
#  Testing Accuracy:-1.0

# %% [markdown]
# <p><center><h1><font color="#730099">HyperParameter Tunning:</font></h1></p></center>

# %%
from sklearn.model_selection import GridSearchCV

# %%
dtc=DecisionTreeClassifier()
param_grid = {
    "criterion":["gini","entropy"],
    "max_depth":list(range(1,20)),
    "min_samples_leaf":list(range(1,20))
}
grid=GridSearchCV(estimator=dtc,param_grid=param_grid,verbose=2)
grid.fit(xs_train,ytrain)
ypred=grid.predict(xs_test)
# Out:
# Fitting 5 folds for each of 722 candidates, totalling 3610 fits
# [CV] END ....criterion=gini, max_depth=1, min_samples_leaf=1; total time=   0.0s
# [CV] END ....criterion=gini, max_depth=1, min_samples_leaf=1; total time=   0.0s
# [CV] END ....criterion=gini, max_depth=1, min_samples_leaf=1; total time=   0.0s
# [CV] END ....criterion=gini, max_depth=1, min_samples_leaf=1; total time=   0.0s
# [CV] END ....criterion=gini, max_depth=1, min_samples_leaf=1; total time=   0.0s
# [CV] END ....criterion=gini, max_depth=1, min_samples_leaf=2; total time=   0.0s
# [CV] END ....criterion=gini, max_depth=1, min_samples_leaf=2; total time=   0.0s
# [CV] END ....criterion=gini, max_depth=1, min_samples_leaf=2; total time=   0.0s
# [CV] END ....criterion=gini, max_depth=1, min_samples_leaf=2; total time=   0.0s
# [CV] END ....criterion=gini, max_depth=1, min_samples_leaf=2; total time=   0.0s
# [CV] END ....criterion=gini, max_depth=1, min_samples_leaf=3; total time=   0.0s
# ...

# %%
grid.best_params_
# Out:
# {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 3}

# %%
print(f'Accuracy Score:- {accuracy_score(ytest,ypred)}')
train = grid.score(xs_train,ytrain)
test = grid.score(xs_test,ytest)
print(f'Training Accuracy:-{train}\n Testing Accuracy:- {test}')
print()
print("Classification_report\n",classification_report(ypred,ytest))
# Out:
# Accuracy Score:- 1.0
# Training Accuracy:-0.9714285714285714
#  Testing Accuracy:- 1.0
#
# Classification_report
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        19
#            1       1.00      1.00      1.00        13
#            2       1.00      1.00      1.00        13
#
#     accuracy                           1.00        45
#    macro avg       1.00      1.00      1.00        45
# weighted avg       1.00      1.00      1.00        45

# %% [markdown]
# <p><center><h1><font color="#730099">Plotting Decision Tree:</font></h1></p></center>

# %%
from sklearn import tree

# %%
fig,ax = plt.subplots(figsize=(15,20))
tree.plot_tree(grid.best_estimator_, filled=True, feature_names=x.columns)
plt.show()

# %% [markdown]
# <p><center><h1><font color="#730099">Bagging:</font></h1></p></center>

# %%
from sklearn.ensemble import BaggingClassifier

# %%
bg = BaggingClassifier(dtc)
bg.fit(xtrain,ytrain)
ypred= bg.predict(xtest)

# %%
train= bg.score(xtrain,ytrain)
test = bg.score(xtest,ytest)
print(f'Training Accuracy:-{train}\n Testing Accuracy:- {test}')
print(classification_report(ytest,ypred))
# Out:
# Training Accuracy:-1.0
#  Testing Accuracy:- 1.0
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        19
#            1       1.00      1.00      1.00        13
#            2       1.00      1.00      1.00        13
#
#     accuracy                           1.00        45
#    macro avg       1.00      1.00      1.00        45
# weighted avg       1.00      1.00      1.00        45

# %% [markdown]
# <p><center><h2><font color="#730099">Defining function for flower prediction :</font></h2></p></center>

# %%
#final model
Final_model=DecisionTreeClassifier()
Final_model.fit(xtrain,ytrain)
# Out:
# DecisionTreeClassifier()

# %%
le.classes_
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
def predict_iris():
    sepl=float(input("Enter Sepal Length (cm)of Flower:- "))
    sepw=float(input("Enter Sepal Width (cm)of Flower:- "))
    petl=float(input("Enter Petal Length (cm)of Flower:- "))
    petw=float(input("Enter Petal Width (cm)of Flower:- "))
    newob = [[sepl,sepw,petl,petw]]
    yp= Final_model.predict(newob)
    print()
    if yp==0:
        print('Iris-setosa Flower')
    elif yp==1:
        print('Iris-versicolor Flower')
    else:
        print('Iris-virginica Flower')
    return yp

# %%
predict_iris()
# Out:
# Enter Sepal Length (cm)of Flower:- 7.7
# Enter Sepal Width (cm)of Flower:- 2.8
# Enter Petal Length (cm)of Flower:- 6.7
# Enter Petal Width (cm)of Flower:- 2
#
# Iris-virginica Flower
# array([2])

# %% [markdown]
# <h1><center><font color="#730099"> Conclusion: </h1></font></center>

# %% [markdown]
# <p><center>In this Python project on Iris flower classification, we successfully developed a machine learning model to classify different species of Iris flowers based on their sepal and petal measurements. We followed a systematic approach, including data exploration, preprocessing, model training, and evaluation.</p></center>
#
# <p><center>Using Python's machine learning libraries, we explored the Iris dataset, visualized the data, and identified patterns between features and target classes. After preprocessing the data and splitting it into training and testing sets, we trained classification models such as logistic regression, decision trees, random forests, or support vector machines. We evaluated the models using accuracy, precision, recall, and F1-score.</p></center>
#
# <p><center>Through model evaluation, we selected the most effective algorithm for Iris flower classification. The chosen model demonstrated high accuracy and precision in predicting the species based on measurements.</p></center>
#
# <p><center>This project highlights the power of Python and its machine learning libraries in solving classification problems. The Iris flower classification project serves as a great introductory example for understanding machine learning fundamentals.</p></center>
#
# <p><center>The insights gained from this project can be applied to various fields, including botany, agriculture, and ecological research. The ability to accurately classify Iris flower species based on physical attributes has practical implications.</p></center>

# %% [markdown]
# ![](class.png)
